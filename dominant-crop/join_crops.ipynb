# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#https://www.nass.usda.gov/Publications/Todays_Reports/reports/acrg0624.pdf

# %%
import os
import pandas as pd

# Define the full list of U.S. states (excluding "United States" aggregate row)
us_states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", "Connecticut", "Delaware",
    "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky",
    "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri",
    "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York",
    "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island",
    "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia",
    "Washington", "West Virginia", "Wisconsin", "Wyoming"
]

# Create an initial dataframe with all states
merged_df = pd.DataFrame({"State": us_states})

# Folder containing CSV files (set to current directory if in the same folder)
folder_path = "data"

# Get list of all CSV files in the folder
csv_files = [f for f in os.listdir(folder_path) if f.endswith(".csv")]

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    crop_name = os.path.splitext(file)[0]  # Extract crop name from file name
    print(crop_name)

    # Read CSV file
    df = pd.read_csv(file_path)

    # Remove "United States" row
    df = df[df["State"] != "United States"]

    # Select only the first (State) and second column
    second_column_name = df.columns[1]  # Get the actual column name
    df = df[["State", second_column_name]].rename(columns={second_column_name: crop_name})

    # Merge with the main dataframe
    merged_df = pd.merge(merged_df, df, on="State", how="left")

# Save merged table to a new CSV file
merged_df.replace("", None).fillna(0)
merged_df.to_csv("merged_crops.csv", index=False)

print("Merged table saved as merged_crops.csv")
# Out:
# sorghum
# soybean
# hay
# flaxseed
# canola
# safflower
# barley
# peanut
# proso_millet
# other_spring_wheat
# dry_edible_pea
# winter_wheat
# sugarbeet
# lentil
# rice
# chickpeas
# rye
# cotton
# sugarcane
# oat
# tobacco
# corn_planted
# sunflower
# wheat
# dry_edible_bean
# potato
# durum_wheat
# Merged table saved as merged_crops.csv

# %%
data_frames[4]
# Out:
#                         State  principal_crop
# State          2022      2023            2024
# Alabama        2120      2120            2120
# Alaska         26          27              29
# Arizona        629        597             642
# Arkansas       6990      7211            7156
# California     2230      2407            2401
# Colorado       5651      5949            5810
# Connecticut    76          77              75
# Delaware       432        438             439
# Florida        1075      1088            1053
# Georgia        3366      3296            3305
# Idaho          4034      4057            4173
# Illinois       22800    22855           22905
# Indiana        11910    11885           11700
# Iowa           24300    24250           24250
# Kansas         24047    25024           24428
# Kentucky       5853      6147            6302
# Louisiana      3204      3214            3225
# Maine          253        242             258
# Maryland       1538      1526            1521
# Massachusetts  74          68              65
# Michigan       6240      6270            6086
# Minnesota      19067    19457           19592
# Mississippi    4202      4209            4182
# Missouri       13852    14657           13356
# Montana        9394      9708            9858
# Nebraska       19268    19473           19813
# Nevada         412        393             373
# New Hampshire  55          54              54
# New Jersey     313        305             286
# New Mexico     787        854             765
# New York       2755      2730            2718
# North Carolina 4404      4397            4215
# North Dakota   21596    24078           23892
# Ohio           9870      9850            9640
# Oklahoma       9616     10724            9566
# Oregon         1739      1852            1899
# Pennsylvania   3523      3395            3456
# Rhode Island   9            8               8
# South Carolina 1462      1423            1430
# South Dakota   16617    17222           16765
# Tennessee      4910      5000            4928
# Texas          21728    22136           21752
# Utah           860        856             882
# Vermont        255        254             254
# Virginia       2441      2583            2555
# Washington     3609      3854            3911
# West Virginia  605        654             640
# Wisconsin      7909      7875            7802
# Wyoming        1442      1416            1367
# United States  310857  319601          315177
