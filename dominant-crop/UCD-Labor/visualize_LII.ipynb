# %%
import pandas as pd
LII_2012 = pd.read_csv("labor_intensity_index_2012.csv")
LII_2017 = pd.read_csv("labor_intensity_index_2017.csv")
LII_2022 = pd.read_csv("labor_intensity_index_2022.csv")

# %%
correlation between workers per acre with entire variable
